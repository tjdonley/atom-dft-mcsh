# %% [markdown]
# # ATOM DFT Dashboard
#
# Run the next cell once. The rest of the notebook is the interactive dashboard: dropdowns, multi-select lists, buttons, progress, plots, descriptors, and batch jobs. No solver parameters need to be edited in code blocks.

# %%
from atom.ui import AtomDFTDashboard

dashboard = AtomDFTDashboard()
dashboard.display()
